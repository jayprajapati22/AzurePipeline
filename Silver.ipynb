# %%
df = spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")
        .load("abfss://bronze@azuredatastor.dfs.core.windows.net/nocs")

# %%
display(df)

# %%
df = df.drop('Country')

# %%
from pyspark.sql.functions import*
from pyspark.sql.types import*
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df = df.withColumnRenamed("tag", split(col('tag'),'-')[0])
df.display()

# %%
df.write.format('delta')\
    .mode("append")\
    .option("path", "abfss://silver@azuredatastor.dfs.core.windows.net/nocs")\
    .save()
